# %%
import numpy as n

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
n.random.randint(2,size=5)
# Out:
# array([1, 0, 0, 1, 0], dtype=int32)

# %%
# Simulate coin flips and calculate probability of heads
num_flips = 12
flips = n.random.randint(2, size=num_flips)
prob_heads = sum(flips) / num_flips
print(f"Probability of heads: {prob_heads}")
# Out:
# Probability of heads: 0.4166666666666667

# %%
def get_real_floor(n):
    if n>1:
        floor=n-1
    elif n==1 or n==0:
        floor=0
    elif n >=2 and n <14:
        floor=n-1
    elif n>=14:
        floor=n-2
    else:
        floor=n
        print("hh",floor)
        print("hh2hh", n ,-n)
    return floor    
get_real_floor(-5)
# Out:
# hh -5
# hh2hh -5 5
# -5

# %%
def get_count(sentence):
    i=sum(1 for char in sentence if char in "aeiou")
    return i  
        
        
get_count("abs udi halla bic AA ku")
# Out:
# 7
